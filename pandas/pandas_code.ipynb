# %%
import pandas as pd

# %%
fpath = '/Users/huajiao/Downloads/kaggle/titanic/train.csv'
datas = pd.read_csv(fpath)
datas.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
datas.shape
# Out:
# (891, 12)

# %%
datas.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
datas.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
datas.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
fpath = '/Users/huajiao/Desktop/data.txt'
datas = pd.read_csv(
    fpath, 
    sep=" ", 
    header=None, 
    names=["Time Step", "flow-time", "jizhu-max(neg)", "jizhu-max(pos)", "jizhu-min(neg)", "jizhu-min(pos)"]
                   )

# %%
datas
# Out:
#    Time Step  flow-time  jizhu-max(neg)  jizhu-max(pos)  jizhu-min(neg)  \
# 0          0          0      273.149994      273.149994      273.149994
# 1          1          4      273.157898      273.157898      273.157837
# 2          2          8      273.167053      273.167053      273.166962
# 3          3         12      273.173462      273.173431      273.173309
# 4          4         16      273.182129      273.182098      273.181915
# 5          5         20      273.191589      273.191559      273.191315
#
#    jizhu-min(pos)
# 0      273.149994
# 1      273.157837
# 2      273.166931
# 3      273.173309
# 4      273.181915
# 5      273.191315

# %%
fpath = '/Users/huajiao/Desktop/test.xlsx'
datas = pd.read_excel(fpath)
datas.head()
# Out:
#    Unnamed: 0      名字      投票人数  类型   产地                 上映时间   时长    年代   评分  \
# 0           0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6
# 1           1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5
# 2           2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5
# 3           3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4
# 4           4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
# !pip install pymysql

# %%
import pymysql
conn = pymysql.connect(
    host = '127.0.0.1',
    user = 'root',
    password = 'MYSQL@ada2',
    database = 'sqllearning',
    charset = 'utf8'
    )

# %%
mysql_page = pd.read_sql("SELECT * FROM prod_info", con=conn)

# %%
mysql_page
# Out:
#    prod_id prod_name brand    type class   cost  sale_price supplier_id
# 0    10001        抽纸    洁柔  120抽*8   日用品  20.11        28.8      NJ0001
# 1    10002        抽纸    维达  120抽*8   日用品  18.02        25.5      NJ0002
# 2    10003        抽纸    洁云  120抽*8   日用品  19.11        26.8      SH0001
# 3    10004       洗衣液   蓝月亮   2.5kg   日用品  33.43        43.8      SH0002
# 4    10005       洗衣液    奥妙   2.5kg   日用品  35.82        49.9      SZ0001
# 5    20001      原味薯片    乐事     80g    零食  11.11        18.3      SZ0002
# 6    20002     黄瓜味薯片    乐事     80g    零食  12.31        18.8      NJ0001
# 7    20003     番茄味薯片    乐事     80g    零食  12.31        18.8      NJ0002
# 8    20004      原味瓜子    洽洽    200g    零食   5.40         8.8      SH0001
# 9    20005      奶油瓜子    洽洽    100g    零食   5.80         9.0      SH0002
# 10   20006      奶油瓜子  良品铺子    200g    零食   5.80         9.5      SZ0001
# 11   20007       趣多多   卡夫卡    280g    零食  13.54        18.6      SZ0002
# ...

# %%
import numpy as np

# %%
s1 = pd.Series([1, 'a', 6, 8, 13])

# %%
s1
# Out:
# 0     1
# 1     a
# 2     6
# 3     8
# 4    13
# dtype: object

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s1.values
# Out:
# array([1, 'a', 6, 8, 13], dtype=object)

# %%
s2 = pd.Series([1, 'a', 6, 8, 13], index=['a', 'b', 'c', 'd', 'e'])

# %%
s2
# Out:
# a     1
# b     a
# c     6
# d     8
# e    13
# dtype: object

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
sdata = {'A':'a','B':'b', 'C':'c'}

# %%
s3 = pd.Series(sdata)

# %%
s3
# Out:
# A    a
# B    b
# C    c
# dtype: object

# %%
s2
# Out:
# a     1
# b     a
# c     6
# d     8
# e    13
# dtype: object

# %%
s2['a']
# Out:
# 1

# %%
type(s2['a'])
# Out:
# int

# %%
s2[['a', 'b']]
# Out:
# a    1
# b    a
# dtype: object

# %%
type(s2[['a', 'b']])
# Out:
# pandas.core.series.Series

# %%
data ={
    'A':['A', 'B', 'C'],
    '1':[1, 2, 3],
    'a':['a', 'b', 'c']
    }
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  1  a
# 0  A  1  a
# 1  B  2  b
# 2  C  3  c

# %%
df.dtypes
# Out:
# A    object
# 1     int64
# a    object
# dtype: object

# %%
df.columns
# Out:
# Index(['A', '1', 'a'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df[['A', 'a']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[2]
# Out:
# A    C
# 1    3
# a    c
# Name: 2, dtype: object

# %%
type(df.loc[2])
# Out:
# pandas.core.series.Series

# %%
df.loc[1:2]  # include 2
# Out:
#    A  1  a
# 1  B  2  b
# 2  C  3  c

# %%
type(df.loc[1:2])
# Out:
# pandas.core.frame.DataFrame

# %%
# Use the data obtained by the crawler.
df = pd.read_excel('/Users/huajiao/Desktop/movies.xlsx')
df.head()
# Out:
#          书名                                         链接   评分     评价数
# 0        活着   https://book.douban.com/subject/4913064/  9.4  639723
# 1       素食者  https://book.douban.com/subject/35534519/  8.1    8450
# 2        鄙视  https://book.douban.com/subject/35482123/  8.0    5265
# 3  房思琪的初恋乐园  https://book.douban.com/subject/27614904/  9.2  279542
# 4     索拉里斯星  https://book.douban.com/subject/35049755/  8.8    6962

# %%
df.set_index('书名', inplace=True)

# %%
df.index
# Out:
# Index(['活着', '素食者', '鄙视', '房思琪的初恋乐园', '索拉里斯星', '蛤蟆先生去看心理医生', '献给阿尔吉侬的花束',
#        '白夜行', '绝叫', '夜晚的潜水艇', '海边的房间', '追风筝的人', '百年孤独', '遥远的救世主', '1984',
#        '解忧杂货店', '焦虑的人', '小王子', '局外人', '红楼梦'],
#       dtype='object', name='书名')

# %%
df.shape
# Out:
# (20, 3)

# %%
df.loc[:, "链接"]
# Out:
# 书名
# 活着             https://book.douban.com/subject/4913064/
# 素食者           https://book.douban.com/subject/35534519/
# 鄙视            https://book.douban.com/subject/35482123/
# 房思琪的初恋乐园      https://book.douban.com/subject/27614904/
# 索拉里斯星         https://book.douban.com/subject/35049755/
# 蛤蟆先生去看心理医生    https://book.douban.com/subject/35143790/
# 献给阿尔吉侬的花束     https://book.douban.com/subject/26362836/
# 白夜行           https://book.douban.com/subject/10554308/
# 绝叫            https://book.douban.com/subject/35031587/
# 夜晚的潜水艇        https://book.douban.com/subject/35005045/
# 海边的房间         https://book.douban.com/subject/35459915/
# 追风筝的人          https://book.douban.com/subject/1770782/
# 百年孤独           https://book.douban.com/subject/6082808/
# 遥远的救世主         https://book.douban.com/subject/1322455/
# 1984           https://book.douban.com/subject/4820710/
# 解忧杂货店         https://book.douban.com/subject/25862578/
# 焦虑的人          https://book.douban.com/subject/35539713/
# ...

# %%
df.loc[:, "链接"] = df["链接"].str.replace("https://book.douban.com/subject", "", regex=True)
df.loc[:, "链接"] = df["链接"].str.replace("/", "", regex=True).astype('int32')

# %%
df.loc[:, "链接"]
# Out:
# 书名
# 活着             4913064
# 素食者           35534519
# 鄙视            35482123
# 房思琪的初恋乐园      27614904
# 索拉里斯星         35049755
# 蛤蟆先生去看心理医生    35143790
# 献给阿尔吉侬的花束     26362836
# 白夜行           10554308
# 绝叫            35031587
# 夜晚的潜水艇        35005045
# 海边的房间         35459915
# 追风筝的人          1770782
# 百年孤独           6082808
# 遥远的救世主         1322455
# 1984           4820710
# 解忧杂货店         25862578
# 焦虑的人          35539713
# 小王子            1084336
# 局外人            4908885
# 红楼梦            1007305
# Name: 链接, dtype: int32

# %%
df.dtypes
# Out:
# 链接       int32
# 评分     float64
# 评价数      int64
# dtype: object

# %%
df.head()
# Out:
#                 链接   评分     评价数
# 书名
# 活着         4913064  9.4  639723
# 素食者       35534519  8.1    8450
# 鄙视        35482123  8.0    5265
# 房思琪的初恋乐园  27614904  9.2  279542
# 索拉里斯星     35049755  8.8    6962

# %%
df.loc['活着', '评分']
# Out:
# 9.4

# %%
df.loc['活着', ['评分', '评价数']]
# Out:
# 评分          9.4
# 评价数    639723.0
# Name: 活着, dtype: float64

# %%
df.loc[['活着', '素食者'], '评分']
# Out:
# 书名
# 活着     9.4
# 素食者    8.1
# Name: 评分, dtype: float64

# %%
df.loc[['活着', '素食者'], ['评分', '评价数']]
# Out:
#       评分     评价数
# 书名
# 活着   9.4  639723
# 素食者  8.1    8450

# %%
df.loc['活着':'鄙视', '评分']
# Out:
# 书名
# 活着     9.4
# 素食者    8.1
# 鄙视     8.0
# Name: 评分, dtype: float64

# %%
df.loc['活着', '链接':'评价数']
# Out:
# 链接     4913064.0
# 评分           9.4
# 评价数     639723.0
# Name: 活着, dtype: float64

# %%
df.loc['活着':'鄙视', '链接':'评价数']
# Out:
#            链接   评分     评价数
# 书名
# 活着    4913064  9.4  639723
# 素食者  35534519  8.1    8450
# 鄙视   35482123  8.0    5265

# %%
df.loc[df['评分']<9, :]
# Out:
#                   链接   评分     评价数
# 书名
# 素食者         35534519  8.1    8450
# 鄙视          35482123  8.0    5265
# 索拉里斯星       35049755  8.8    6962
# 蛤蟆先生去看心理医生  35143790  8.5   56658
# 绝叫          35031587  8.7   24658
# 夜晚的潜水艇      35005045  8.4   28881
# 海边的房间       35459915  8.1    6531
# 追风筝的人        1770782  8.9  719528
# 遥远的救世主       1322455  8.7   22529
# 解忧杂货店       25862578  8.5  700432
# 焦虑的人        35539713  8.3    2151

# %%
df['评分']<9
# Out:
# 书名
# 活着            False
# 素食者            True
# 鄙视             True
# 房思琪的初恋乐园      False
# 索拉里斯星          True
# 蛤蟆先生去看心理医生     True
# 献给阿尔吉侬的花束     False
# 白夜行           False
# 绝叫             True
# 夜晚的潜水艇         True
# 海边的房间          True
# 追风筝的人          True
# 百年孤独          False
# 遥远的救世主         True
# 1984          False
# 解忧杂货店          True
# 焦虑的人           True
# 小王子           False
# 局外人           False
# 红楼梦           False
# Name: 评分, dtype: bool

# %%
df.loc[(df['评分']>9.2) & (df['评价数']>10000), :]
# Out:
#            链接   评分     评价数
# 书名
# 活着    4913064  9.4  639723
# 百年孤独  6082808  9.3  356153
# 1984  4820710  9.4  197605
# 红楼梦   1007305  9.6  353367

# %%
df.loc[lambda df:(df['评分']>9.2) & (df['评价数']>10000), :]
# Out:
#            链接   评分     评价数
# 书名
# 活着    4913064  9.4  639723
# 百年孤独  6082808  9.3  356153
# 1984  4820710  9.4  197605
# 红楼梦   1007305  9.6  353367

# %%
def query_my_data(df):
    return (df['评分']>9.2) & (df['评分']>9.2)

df.loc[query_my_data, :]
# Out:
#            链接   评分     评价数
# 书名
# 活着    4913064  9.4  639723
# 百年孤独  6082808  9.3  356153
# 1984  4820710  9.4  197605
# 红楼梦   1007305  9.6  353367

# %%
df3 = pd.DataFrame({'ymd':["2019-01-01", "2019-03-01", "2019-01-25"], 'temp':[21, 23, 31]})
df3.set_index('ymd', inplace=True)
df3.index
# Out:
# Index(['2019-01-01', '2019-03-01', '2019-01-25'], dtype='object', name='ymd')

# %%
df3.index.str.startswith('2019-01')
# Out:
# array([ True, False,  True])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 活着 to 红楼梦
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   链接      20 non-null     int32
#  1   评分      20 non-null     float64
#  2   评价数     20 non-null     int64
# dtypes: float64(1), int32(1), int64(1)
# memory usage: 1.1+ KB

# %%
df['评价数'].astype('float64')
df.loc[:, "评分总和"] = df['评分'] * df['评价数']

# %%
df
# Out:
#                   链接   评分     评价数       评分总和
# 书名
# 活着           4913064  9.4  639723  6013396.2
# 素食者         35534519  8.1    8450    68445.0
# 鄙视          35482123  8.0    5265    42120.0
# 房思琪的初恋乐园    27614904  9.2  279542  2571786.4
# 索拉里斯星       35049755  8.8    6962    61265.6
# 蛤蟆先生去看心理医生  35143790  8.5   56658   481593.0
# 献给阿尔吉侬的花束   26362836  9.1   40339   367084.9
# 白夜行         10554308  9.1  371533  3380950.3
# 绝叫          35031587  8.7   24658   214524.6
# 夜晚的潜水艇      35005045  8.4   28881   242600.4
# 海边的房间       35459915  8.1    6531    52901.1
# 追风筝的人        1770782  8.9  719528  6403799.2
# 百年孤独         6082808  9.3  356153  3312222.9
# 遥远的救世主       1322455  8.7   22529   196002.3
# 1984         4820710  9.4  197605  1857487.0
# 解忧杂货店       25862578  8.5  700432  5953672.0
# 焦虑的人        35539713  8.3    2151    17853.3
# 小王子          1084336  9.0  662934  5966406.0
# 局外人          4908885  9.0  180153  1621377.0
# 红楼梦          1007305  9.6  353367  3392323.2

# %%
def get_good_movies(x):
    if x['评分'] > 9.2:
        return 'great'
    if x['评分'] < 8.8:
        return 'normal'
    return 'good'

df.loc[:, "movie_type"] = df.apply(get_good_movies, axis=1)

# %%
df
# Out:
#                   链接   评分     评价数       评分总和 movie_type
# 书名
# 活着           4913064  9.4  639723  6013396.2      great
# 素食者         35534519  8.1    8450    68445.0     normal
# 鄙视          35482123  8.0    5265    42120.0     normal
# 房思琪的初恋乐园    27614904  9.2  279542  2571786.4       good
# 索拉里斯星       35049755  8.8    6962    61265.6       good
# 蛤蟆先生去看心理医生  35143790  8.5   56658   481593.0     normal
# 献给阿尔吉侬的花束   26362836  9.1   40339   367084.9       good
# 白夜行         10554308  9.1  371533  3380950.3       good
# 绝叫          35031587  8.7   24658   214524.6     normal
# 夜晚的潜水艇      35005045  8.4   28881   242600.4     normal
# 海边的房间       35459915  8.1    6531    52901.1     normal
# 追风筝的人        1770782  8.9  719528  6403799.2       good
# 百年孤独         6082808  9.3  356153  3312222.9      great
# 遥远的救世主       1322455  8.7   22529   196002.3     normal
# 1984         4820710  9.4  197605  1857487.0      great
# 解忧杂货店       25862578  8.5  700432  5953672.0     normal
# ...

# %%
df["movie_type"].value_counts()
# Out:
# normal    9
# good      7
# great     4
# Name: movie_type, dtype: int64

# %%
# new column
df.assign(points5 = lambda x : x['评分']-5,
          points8 = lambda x : x['评分']-8
         )
# Out:
#                   链接   评分     评价数       评分总和 movie_type  points5  points8
# 书名
# 活着           4913064  9.4  639723  6013396.2      great      4.4      1.4
# 素食者         35534519  8.1    8450    68445.0     normal      3.1      0.1
# 鄙视          35482123  8.0    5265    42120.0     normal      3.0      0.0
# 房思琪的初恋乐园    27614904  9.2  279542  2571786.4       good      4.2      1.2
# 索拉里斯星       35049755  8.8    6962    61265.6       good      3.8      0.8
# 蛤蟆先生去看心理医生  35143790  8.5   56658   481593.0     normal      3.5      0.5
# 献给阿尔吉侬的花束   26362836  9.1   40339   367084.9       good      4.1      1.1
# 白夜行         10554308  9.1  371533  3380950.3       good      4.1      1.1
# 绝叫          35031587  8.7   24658   214524.6     normal      3.7      0.7
# 夜晚的潜水艇      35005045  8.4   28881   242600.4     normal      3.4      0.4
# 海边的房间       35459915  8.1    6531    52901.1     normal      3.1      0.1
# 追风筝的人        1770782  8.9  719528  6403799.2       good      3.9      0.9
# ...

# %%
df.head(3)
# Out:
#            链接   评分     评价数       评分总和 movie_type
# 书名
# 活着    4913064  9.4  639723  6013396.2      great
# 素食者  35534519  8.1    8450    68445.0     normal
# 鄙视   35482123  8.0    5265    42120.0     normal

# %%
df['movie_view'] = ''
df.loc[df['评分']*df['评价数']>80000, 'movie_view'] = 'big'
df.loc[df['评分']*df['评价数']<=80000, 'movie_view'] = 'small'

# %%
df['movie_view'].value_counts()
# Out:
# big      15
# small     5
# Name: movie_view, dtype: int64

# %%
df.describe()
# Out:
#                  链接         评分            评价数          评分总和
# count  2.000000e+01  20.000000      20.000000  2.000000e+01
# mean   1.992757e+07   8.805000  233169.700000  2.110891e+06
# std    1.516494e+07   0.474036  263185.827056  2.364459e+06
# min    1.007305e+06   8.000000    2151.000000  1.785330e+04
# 25%    4.886841e+06   8.475000   19009.250000  1.641130e+05
# 50%    2.611271e+07   8.850000  118405.500000  1.051485e+06
# 75%    3.507326e+07   9.125000  359998.000000  3.383794e+06
# max    3.553971e+07   9.600000  719528.000000  6.403799e+06

# %%
df['评分'].mean()
# Out:
# 8.805000000000001

# %%
df['评分'].min()
# Out:
# 8.0

# %%
df['评分'].max()
# Out:
# 9.6

# %%
df['movie_type'].unique()
# Out:
# array(['great', 'normal', 'good'], dtype=object)

# %%
df['movie_view'].unique()
# Out:
# array(['big', 'small'], dtype=object)

# %%
df.cov()
# Out:
#                 链接            评分           评价数          评分总和
# 链接    2.299754e+14 -5.294706e+06 -2.509512e+12 -2.322804e+13
# 评分   -5.294706e+06  2.247105e-01  6.087506e+04  5.787492e+05
# 评价数  -2.509512e+12  6.087506e+04  6.926678e+10  6.215365e+11
# 评分总和 -2.322804e+13  5.787492e+05  6.215365e+11  5.590665e+12

# %%
df.corr()
# Out:
#             链接        评分       评价数      评分总和
# 链接    1.000000 -0.736528 -0.628762 -0.647799
# 评分   -0.736528  1.000000  0.487939  0.516353
# 评价数  -0.628762  0.487939  1.000000  0.998786
# 评分总和 -0.647799  0.516353  0.998786  1.000000

# %%
df['评分'].corr(df['评价数'])
# Out:
# 0.48793866027476457

# %%
df['评分'].corr(df['链接'])
# Out:
# -0.7365282184674817

# %%
df['评价数'].corr(df['链接'])
# Out:
# -0.6287615609761954

# %%
# isnull, notnull
# dropna: axis, how='any'/'all', inplace
# fillna: value, method, axis, inplace
df_book = pd.read_excel('/Users/huajiao/Desktop/Book1.xlsx', skiprows=2)

# %%
df_book
# Out:
#     Unnamed: 0  Unnamed: 1   姓名   科目    分数
# 0          NaN         NaN   小明   语文  85.0
# 1          NaN         NaN  NaN   数学  80.0
# 2          NaN         NaN  NaN   英语  90.0
# 3          NaN         NaN  NaN  NaN   NaN
# 4          NaN         NaN   小王   语文  85.0
# 5          NaN         NaN  NaN   数学   NaN
# 6          NaN         NaN  NaN   英语  90.0
# 7          NaN         NaN  NaN  NaN   NaN
# 8          NaN         NaN   小刚   语文  85.0
# 9          NaN         NaN  NaN   数学  80.0
# 10         NaN         NaN  NaN   英语  90.0

# %%
df_book.isnull()
# Out:
#     Unnamed: 0  Unnamed: 1     姓名     科目     分数
# 0         True        True  False  False  False
# 1         True        True   True  False  False
# 2         True        True   True  False  False
# 3         True        True   True   True   True
# 4         True        True  False  False  False
# 5         True        True   True  False   True
# 6         True        True   True  False  False
# 7         True        True   True   True   True
# 8         True        True  False  False  False
# 9         True        True   True  False  False
# 10        True        True   True  False  False

# %%
df_book['分数'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# Name: 分数, dtype: bool

# %%
df_book['分数'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8      True
# 9      True
# 10     True
# Name: 分数, dtype: bool

# %%
df_book.loc[df_book['分数'].notnull(), :]
# Out:
#     Unnamed: 0  Unnamed: 1   姓名  科目    分数
# 0          NaN         NaN   小明  语文  85.0
# 1          NaN         NaN  NaN  数学  80.0
# 2          NaN         NaN  NaN  英语  90.0
# 4          NaN         NaN   小王  语文  85.0
# 6          NaN         NaN  NaN  英语  90.0
# 8          NaN         NaN   小刚  语文  85.0
# 9          NaN         NaN  NaN  数学  80.0
# 10         NaN         NaN  NaN  英语  90.0

# %%
df_book.dropna(axis="columns", how='all', inplace=True)

# %%
df_book
# Out:
#      姓名   科目    分数
# 0    小明   语文  85.0
# 1   NaN   数学  80.0
# 2   NaN   英语  90.0
# 3   NaN  NaN   NaN
# 4    小王   语文  85.0
# 5   NaN   数学   NaN
# 6   NaN   英语  90.0
# 7   NaN  NaN   NaN
# 8    小刚   语文  85.0
# 9   NaN   数学  80.0
# 10  NaN   英语  90.0

# %%
df_book.dropna(axis="rows", how='all', inplace=True)

# %%
df_book
# Out:
#      姓名  科目    分数
# 0    小明  语文  85.0
# 1   NaN  数学  80.0
# 2   NaN  英语  90.0
# 4    小王  语文  85.0
# 5   NaN  数学   NaN
# 6   NaN  英语  90.0
# 8    小刚  语文  85.0
# 9   NaN  数学  80.0
# 10  NaN  英语  90.0

# %%
df_book.fillna({'分数':0})
# Out:
#      姓名  科目    分数
# 0    小明  语文  85.0
# 1   NaN  数学  80.0
# 2   NaN  英语  90.0
# 4    小王  语文  85.0
# 5   NaN  数学   0.0
# 6   NaN  英语  90.0
# 8    小刚  语文  85.0
# 9   NaN  数学  80.0
# 10  NaN  英语  90.0

# %%
df_book.loc[:, '分数'] = df_book['分数'].fillna(0)

# %%
df_book.loc[:, '姓名'] = df_book['姓名'].fillna(method='ffill')

# %%
df_book
# Out:
#     姓名  科目    分数
# 0   小明  语文  85.0
# 1   小明  数学  80.0
# 2   小明  英语  90.0
# 4   小王  语文  85.0
# 5   小王  数学   0.0
# 6   小王  英语  90.0
# 8   小刚  语文  85.0
# 9   小刚  数学  80.0
# 10  小刚  英语  90.0

# %%
df_book.to_excel('/Users/huajiao/Desktop/Book1_clean.xlsx', index=False)

# %%
# SettingWithCopyWarning:
# df['condition']['xxx'] = df['xxxx'] - df['x']
# equal to df.get(condition).set('xxx'), get is not ok.
# cannot tell it is a view or copy.
# cannot select and rewrite in one operation

# solutions 1: set operation
# df.loc[condition, 'xxx'] = df['xxxx'] - df['x']
# solutions 2: new DataFrame
# df_new = df[condition].copy()
# df_new['xxx'] = df['xxxx'] - df['x']

# %%
df['评分'].sort_values()
# Out:
# 书名
# 鄙视            8.0
# 素食者           8.1
# 海边的房间         8.1
# 焦虑的人          8.3
# 夜晚的潜水艇        8.4
# 蛤蟆先生去看心理医生    8.5
# 解忧杂货店         8.5
# 遥远的救世主        8.7
# 绝叫            8.7
# 索拉里斯星         8.8
# 追风筝的人         8.9
# 局外人           9.0
# 小王子           9.0
# 献给阿尔吉侬的花束     9.1
# 白夜行           9.1
# 房思琪的初恋乐园      9.2
# 百年孤独          9.3
# 活着            9.4
# 1984          9.4
# 红楼梦           9.6
# Name: 评分, dtype: float64

# %%
df['评分'].sort_values(ascending=False)
# Out:
# 书名
# 红楼梦           9.6
# 1984          9.4
# 活着            9.4
# 百年孤独          9.3
# 房思琪的初恋乐园      9.2
# 献给阿尔吉侬的花束     9.1
# 白夜行           9.1
# 局外人           9.0
# 小王子           9.0
# 追风筝的人         8.9
# 索拉里斯星         8.8
# 遥远的救世主        8.7
# 绝叫            8.7
# 解忧杂货店         8.5
# 蛤蟆先生去看心理医生    8.5
# 夜晚的潜水艇        8.4
# 焦虑的人          8.3
# 素食者           8.1
# 海边的房间         8.1
# 鄙视            8.0
# Name: 评分, dtype: float64

# %%
df.sort_values(by="评分")
# Out:
#                   链接   评分     评价数       评分总和 movie_type movie_view
# 书名
# 鄙视          35482123  8.0    5265    42120.0     normal      small
# 素食者         35534519  8.1    8450    68445.0     normal      small
# 海边的房间       35459915  8.1    6531    52901.1     normal      small
# 焦虑的人        35539713  8.3    2151    17853.3     normal      small
# 夜晚的潜水艇      35005045  8.4   28881   242600.4     normal        big
# 蛤蟆先生去看心理医生  35143790  8.5   56658   481593.0     normal        big
# 解忧杂货店       25862578  8.5  700432  5953672.0     normal        big
# 遥远的救世主       1322455  8.7   22529   196002.3     normal        big
# 绝叫          35031587  8.7   24658   214524.6     normal        big
# 索拉里斯星       35049755  8.8    6962    61265.6       good      small
# 追风筝的人        1770782  8.9  719528  6403799.2       good        big
# 局外人          4908885  9.0  180153  1621377.0       good        big
# 小王子          1084336  9.0  662934  5966406.0       good        big
# ...

# %%
df.sort_values(by="评分", ascending=False)
# Out:
#                   链接   评分     评价数       评分总和 movie_type movie_view
# 书名
# 红楼梦          1007305  9.6  353367  3392323.2      great        big
# 1984         4820710  9.4  197605  1857487.0      great        big
# 活着           4913064  9.4  639723  6013396.2      great        big
# 百年孤独         6082808  9.3  356153  3312222.9      great        big
# 房思琪的初恋乐园    27614904  9.2  279542  2571786.4       good        big
# 献给阿尔吉侬的花束   26362836  9.1   40339   367084.9       good        big
# 白夜行         10554308  9.1  371533  3380950.3       good        big
# 局外人          4908885  9.0  180153  1621377.0       good        big
# 小王子          1084336  9.0  662934  5966406.0       good        big
# 追风筝的人        1770782  8.9  719528  6403799.2       good        big
# 索拉里斯星       35049755  8.8    6962    61265.6       good      small
# 遥远的救世主       1322455  8.7   22529   196002.3     normal        big
# 绝叫          35031587  8.7   24658   214524.6     normal        big
# ...

# %%
df.sort_values(by=["评分", "评价数"], ascending=False)
# Out:
#                   链接   评分     评价数       评分总和 movie_type movie_view
# 书名
# 红楼梦          1007305  9.6  353367  3392323.2      great        big
# 活着           4913064  9.4  639723  6013396.2      great        big
# 1984         4820710  9.4  197605  1857487.0      great        big
# 百年孤独         6082808  9.3  356153  3312222.9      great        big
# 房思琪的初恋乐园    27614904  9.2  279542  2571786.4       good        big
# 白夜行         10554308  9.1  371533  3380950.3       good        big
# 献给阿尔吉侬的花束   26362836  9.1   40339   367084.9       good        big
# 小王子          1084336  9.0  662934  5966406.0       good        big
# 局外人          4908885  9.0  180153  1621377.0       good        big
# 追风筝的人        1770782  8.9  719528  6403799.2       good        big
# 索拉里斯星       35049755  8.8    6962    61265.6       good      small
# 绝叫          35031587  8.7   24658   214524.6     normal        big
# 遥远的救世主       1322455  8.7   22529   196002.3     normal        big
# ...

# %%
df.sort_values(by=["评分", "评价数"], ascending=[False, True])
# Out:
#                   链接   评分     评价数       评分总和 movie_type movie_view
# 书名
# 红楼梦          1007305  9.6  353367  3392323.2      great        big
# 1984         4820710  9.4  197605  1857487.0      great        big
# 活着           4913064  9.4  639723  6013396.2      great        big
# 百年孤独         6082808  9.3  356153  3312222.9      great        big
# 房思琪的初恋乐园    27614904  9.2  279542  2571786.4       good        big
# 献给阿尔吉侬的花束   26362836  9.1   40339   367084.9       good        big
# 白夜行         10554308  9.1  371533  3380950.3       good        big
# 局外人          4908885  9.0  180153  1621377.0       good        big
# 小王子          1084336  9.0  662934  5966406.0       good        big
# 追风筝的人        1770782  8.9  719528  6403799.2       good        big
# 索拉里斯星       35049755  8.8    6962    61265.6       good      small
# 遥远的救世主       1322455  8.7   22529   196002.3     normal        big
# 绝叫          35031587  8.7   24658   214524.6     normal        big
# ...

# %%
df = pd.read_excel('/Users/huajiao/Desktop/movies.xlsx')

# %%
df
# Out:
#             书名                                         链接   评分     评价数
# 0           活着   https://book.douban.com/subject/4913064/  9.4  639723
# 1          素食者  https://book.douban.com/subject/35534519/  8.1    8450
# 2           鄙视  https://book.douban.com/subject/35482123/  8.0    5265
# 3     房思琪的初恋乐园  https://book.douban.com/subject/27614904/  9.2  279542
# 4        索拉里斯星  https://book.douban.com/subject/35049755/  8.8    6962
# 5   蛤蟆先生去看心理医生  https://book.douban.com/subject/35143790/  8.5   56658
# 6    献给阿尔吉侬的花束  https://book.douban.com/subject/26362836/  9.1   40339
# 7          白夜行  https://book.douban.com/subject/10554308/  9.1  371533
# 8           绝叫  https://book.douban.com/subject/35031587/  8.7   24658
# 9       夜晚的潜水艇  https://book.douban.com/subject/35005045/  8.4   28881
# 10       海边的房间  https://book.douban.com/subject/35459915/  8.1    6531
# 11       追风筝的人   https://book.douban.com/subject/1770782/  8.9  719528
# ...

# %%
df.dtypes
# Out:
# 书名      object
# 链接      object
# 评分     float64
# 评价数      int64
# dtype: object

# %%
df['链接'].str

# %%
df['链接'].str.isnumeric()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: 链接, dtype: bool

# %%
condition = df['链接'].str.startswith('https://book.douban.com/subject/')

# %%
condition
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# Name: 链接, dtype: bool

# %%
df[condition].head()
# Out:
#          书名                                         链接   评分     评价数
# 0        活着   https://book.douban.com/subject/4913064/  9.4  639723
# 1       素食者  https://book.douban.com/subject/35534519/  8.1    8450
# 2        鄙视  https://book.douban.com/subject/35482123/  8.0    5265
# 3  房思琪的初恋乐园  https://book.douban.com/subject/27614904/  9.2  279542
# 4     索拉里斯星  https://book.douban.com/subject/35049755/  8.8    6962

# %%
df["链接"].str.replace("https://book.douban.com/subject", "", regex=True)
# Out:
# 0      /4913064/
# 1     /35534519/
# 2     /35482123/
# 3     /27614904/
# 4     /35049755/
# 5     /35143790/
# 6     /26362836/
# 7     /10554308/
# 8     /35031587/
# 9     /35005045/
# 10    /35459915/
# 11     /1770782/
# 12     /6082808/
# 13     /1322455/
# 14     /4820710/
# 15    /25862578/
# 16    /35539713/
# 17     /1084336/
# 18     /4908885/
# 19     /1007305/
# Name: 链接, dtype: object

# %%
df["链接"].str.replace("/", "").str.slice(6,10)
df
# Out:
#             书名                                         链接   评分     评价数
# 0           活着   https://book.douban.com/subject/4913064/  9.4  639723
# 1          素食者  https://book.douban.com/subject/35534519/  8.1    8450
# 2           鄙视  https://book.douban.com/subject/35482123/  8.0    5265
# 3     房思琪的初恋乐园  https://book.douban.com/subject/27614904/  9.2  279542
# 4        索拉里斯星  https://book.douban.com/subject/35049755/  8.8    6962
# 5   蛤蟆先生去看心理医生  https://book.douban.com/subject/35143790/  8.5   56658
# 6    献给阿尔吉侬的花束  https://book.douban.com/subject/26362836/  9.1   40339
# 7          白夜行  https://book.douban.com/subject/10554308/  9.1  371533
# 8           绝叫  https://book.douban.com/subject/35031587/  8.7   24658
# 9       夜晚的潜水艇  https://book.douban.com/subject/35005045/  8.4   28881
# 10       海边的房间  https://book.douban.com/subject/35459915/  8.1    6531
# 11       追风筝的人   https://book.douban.com/subject/1770782/  8.9  719528
# ...

# %%
df["链接"].str.replace("/", "").str[6:10]
# Out:
# 0     book
# 1     book
# 2     book
# 3     book
# 4     book
# 5     book
# 6     book
# 7     book
# 8     book
# 9     book
# 10    book
# 11    book
# 12    book
# 13    book
# 14    book
# 15    book
# 16    book
# 17    book
# 18    book
# 19    book
# Name: 链接, dtype: object

# %%
def get_id(x):
    x1 = x['链接'].split('/')
    return f"id_{x1[-2]}_2022"
df['id'] = df.apply(get_id, axis=1)
df
# Out:
#             书名                                         链接   评分     评价数  \
# 0           活着   https://book.douban.com/subject/4913064/  9.4  639723
# 1          素食者  https://book.douban.com/subject/35534519/  8.1    8450
# 2           鄙视  https://book.douban.com/subject/35482123/  8.0    5265
# 3     房思琪的初恋乐园  https://book.douban.com/subject/27614904/  9.2  279542
# 4        索拉里斯星  https://book.douban.com/subject/35049755/  8.8    6962
# 5   蛤蟆先生去看心理医生  https://book.douban.com/subject/35143790/  8.5   56658
# 6    献给阿尔吉侬的花束  https://book.douban.com/subject/26362836/  9.1   40339
# 7          白夜行  https://book.douban.com/subject/10554308/  9.1  371533
# 8           绝叫  https://book.douban.com/subject/35031587/  8.7   24658
# 9       夜晚的潜水艇  https://book.douban.com/subject/35005045/  8.4   28881
# 10       海边的房间  https://book.douban.com/subject/35459915/  8.1    6531
# 11       追风筝的人   https://book.douban.com/subject/1770782/  8.9  719528
# ...

# %%
df['id']
# Out:
# 0      id_4913064_2022
# 1     id_35534519_2022
# 2     id_35482123_2022
# 3     id_27614904_2022
# 4     id_35049755_2022
# 5     id_35143790_2022
# 6     id_26362836_2022
# 7     id_10554308_2022
# 8     id_35031587_2022
# 9     id_35005045_2022
# 10    id_35459915_2022
# 11     id_1770782_2022
# 12     id_6082808_2022
# 13     id_1322455_2022
# 14     id_4820710_2022
# 15    id_25862578_2022
# 16    id_35539713_2022
# 17     id_1084336_2022
# 18     id_4908885_2022
# 19     id_1007305_2022
# Name: id, dtype: object

# %%
df['id'].str.replace('id_','').str.replace('_2022','')
# Out:
# 0      4913064
# 1     35534519
# 2     35482123
# 3     27614904
# 4     35049755
# 5     35143790
# 6     26362836
# 7     10554308
# 8     35031587
# 9     35005045
# 10    35459915
# 11     1770782
# 12     6082808
# 13     1322455
# 14     4820710
# 15    25862578
# 16    35539713
# 17     1084336
# 18     4908885
# 19     1007305
# Name: id, dtype: object

# %%
df['id'].str.replace('[id__2022]', '', regex=True)
# Out:
# 0       491364
# 1     35534519
# 2       354813
# 3       761494
# 4      3549755
# 5      3514379
# 6       636836
# 7       155438
# 8      3531587
# 9        35545
# 10    35459915
# 11       17778
# 12        6888
# 13       13455
# 14        4871
# 15      586578
# 16    35539713
# 17      184336
# 18      498885
# 19        1735
# Name: id, dtype: object

# %%
df1 = pd.DataFrame(
    np.arange(12).reshape(3,4),
    columns=['A', 'B', 'C', 'D']
    )

# %%
df1
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df1.drop('A', axis=1)
# Out:
#    B   C   D
# 0  1   2   3
# 1  5   6   7
# 2  9  10  11

# %%
df1.drop(1, axis=0)
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 2  8  9  10  11

# %%
df1.mean(axis=0)
# Out:
# A    4.0
# B    5.0
# C    6.0
# D    7.0
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# 0    1.5
# 1    5.5
# 2    9.5
# dtype: float64

# %%
def get_sum_value(x):
    return x['A'] + x['B'] + x['C'] + x['D']
df1['sum_values'] = df1.apply(get_sum_value, axis=1)

# %%
df1
# Out:
#    A  B   C   D  sum_values
# 0  0  1   2   3           6
# 1  4  5   6   7          22
# 2  8  9  10  11          38

# %%
df.set_index('id', inplace=True, drop=False)
df
# Out:
#                           书名                                         链接   评分  \
# id
# id_4913064_2022           活着   https://book.douban.com/subject/4913064/  9.4
# id_35534519_2022         素食者  https://book.douban.com/subject/35534519/  8.1
# id_35482123_2022          鄙视  https://book.douban.com/subject/35482123/  8.0
# id_27614904_2022    房思琪的初恋乐园  https://book.douban.com/subject/27614904/  9.2
# id_35049755_2022       索拉里斯星  https://book.douban.com/subject/35049755/  8.8
# id_35143790_2022  蛤蟆先生去看心理医生  https://book.douban.com/subject/35143790/  8.5
# id_26362836_2022   献给阿尔吉侬的花束  https://book.douban.com/subject/26362836/  9.1
# id_10554308_2022         白夜行  https://book.douban.com/subject/10554308/  9.1
# id_35031587_2022          绝叫  https://book.douban.com/subject/35031587/  8.7
# id_35005045_2022      夜晚的潜水艇  https://book.douban.com/subject/35005045/  8.4
# id_35459915_2022       海边的房间  https://book.douban.com/subject/35459915/  8.1
# ...

# %%
df.index
# Out:
# Index(['id_4913064_2022', 'id_35534519_2022', 'id_35482123_2022',
#        'id_27614904_2022', 'id_35049755_2022', 'id_35143790_2022',
#        'id_26362836_2022', 'id_10554308_2022', 'id_35031587_2022',
#        'id_35005045_2022', 'id_35459915_2022', 'id_1770782_2022',
#        'id_6082808_2022', 'id_1322455_2022', 'id_4820710_2022',
#        'id_25862578_2022', 'id_35539713_2022', 'id_1084336_2022',
#        'id_4908885_2022', 'id_1007305_2022'],
#       dtype='object', name='id')

# %%
df.loc['id_10554308_2022'].head(4)
# Out:
# 书名                                           白夜行
# 链接     https://book.douban.com/subject/10554308/
# 评分                                           9.1
# 评价数                                       371533
# Name: id_10554308_2022, dtype: object

# %%
df.loc[df['id'] =='id_10554308_2022'].head(4)
# Out:
#                    书名                                         链接   评分     评价数  \
# id
# id_10554308_2022  白夜行  https://book.douban.com/subject/10554308/  9.1  371533
#
#                                 id
# id
# id_10554308_2022  id_10554308_2022

# %%
from sklearn.utils import shuffle

# %%
df_shuffle = shuffle(df)
df_shuffle.head()
# Out:
#                      书名                                         链接   评分  \
# id
# id_35534519_2022    素食者  https://book.douban.com/subject/35534519/  8.1
# id_35539713_2022   焦虑的人  https://book.douban.com/subject/35539713/  8.3
# id_4908885_2022     局外人   https://book.douban.com/subject/4908885/  9.0
# id_35031587_2022     绝叫  https://book.douban.com/subject/35031587/  8.7
# id_35049755_2022  索拉里斯星  https://book.douban.com/subject/35049755/  8.8
#
#                      评价数                id
# id
# id_35534519_2022    8450  id_35534519_2022
# id_35539713_2022    2151  id_35539713_2022
# id_4908885_2022   180153   id_4908885_2022
# id_35031587_2022   24658  id_35031587_2022
# id_35049755_2022    6962  id_35049755_2022

# %%
df_shuffle.index.is_monotonic_increasing
# Out:
# False

# %%
df_shuffle.index.is_unique  # O(1)
# Out:
# True

# %%
# %timeit df_shuffle.loc['id_10554308_2022']
# Out:
# 147 µs ± 19.4 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
df_sorted = df_shuffle.sort_index()

# %%
df_sorted.head()
# Out:
#                       书名                                         链接   评分  \
# id
# id_1007305_2022      红楼梦   https://book.douban.com/subject/1007305/  9.6
# id_10554308_2022     白夜行  https://book.douban.com/subject/10554308/  9.1
# id_1084336_2022      小王子   https://book.douban.com/subject/1084336/  9.0
# id_1322455_2022   遥远的救世主   https://book.douban.com/subject/1322455/  8.7
# id_1770782_2022    追风筝的人   https://book.douban.com/subject/1770782/  8.9
#
#                      评价数                id
# id
# id_1007305_2022   353367   id_1007305_2022
# id_10554308_2022  371533  id_10554308_2022
# id_1084336_2022   662934   id_1084336_2022
# id_1322455_2022    22529   id_1322455_2022
# id_1770782_2022   719528   id_1770782_2022

# %%
df_shuffle.index.is_monotonic_increasing
# Out:
# False

# %%
# %timeit df_shuffle.loc['id_10554308_2022']  # O(1)
# Out:
# 112 µs ± 5.51 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
s1 = pd.Series([1, 2, 3], index=list('abc'))

# %%
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s2 = pd.Series([2, 3, 4], index=list('bcd'))

# %%
s2
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %%
s1 + s2
# Out:
# a    NaN
# b    4.0
# c    6.0
# d    NaN
# dtype: float64

# %%
# CategoricalIndex, MultiIndex, DatetimeIndex

# %%
# pd.merge() https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
# http://files.grouplens.org/datasets/movielens/

df_ratings = pd.read_csv('/Users/huajiao/Downloads/ml-1m/ratings.dat', 
                         sep='::',
                         engine='python',
                         names='UserID::MovieID::Rating::Timestamp'.split('::')
                        )

# %%
df_ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
df_movies = pd.read_csv('/Users/huajiao/Downloads/ml-1m/movies.dat', 
                         sep='::',
                         engine='python',
                         names='MovieID::Tittle::Genres'.split('::')
                        )

# %%
df_movies.head()
# Out:
#    MovieID                              Tittle                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
df_users = pd.read_csv('/Users/huajiao/Downloads/ml-1m/users.dat', 
                         sep='::',
                         engine='python',
                         names='UserID::Gender::Ages::Occupation::Zip-code'.split('::')
                        )

# %%
df_users.head()
# Out:
#    UserID Gender  Ages  Occupation Zip-code
# 0       1      F     1          10    48067
# 1       2      M    56          16    70072
# 2       3      M    25          15    55117
# 3       4      M    45           7    02460
# 4       5      M    25          20    55455

# %%
df_ratings_users = pd.merge(
    df_ratings, df_users, left_on='UserID', right_on='UserID', how='inner'
)

# %%
df_ratings_users.head()
# Out:
#    UserID  MovieID  Rating  Timestamp Gender  Ages  Occupation Zip-code
# 0       1     1193       5  978300760      F     1          10    48067
# 1       1      661       3  978302109      F     1          10    48067
# 2       1      914       3  978301968      F     1          10    48067
# 3       1     3408       4  978300275      F     1          10    48067
# 4       1     2355       5  978824291      F     1          10    48067

# %%
df_ratings_users_movies = pd.merge(
    df_ratings_users, df_movies, left_on='MovieID', right_on='MovieID', how='inner'
)

# %%
df_ratings_users_movies.head()
# Out:
#    UserID  MovieID  Rating  Timestamp Gender  Ages  Occupation Zip-code  \
# 0       1     1193       5  978300760      F     1          10    48067
# 1       2     1193       5  978298413      M    56          16    70072
# 2      12     1193       4  978220179      M    25          12    32793
# 3      15     1193       4  978199279      M    25           7    22903
# 4      17     1193       5  978158471      M    50           1    95350
#
#                                    Tittle Genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                    'A':['A0', 'A1', 'A2', 'A3'],
                    'B':['B0', 'B1', 'B2', 'B3']})
right = pd.DataFrame({'key': ['K0', 'K1', 'K4', 'K5'],
                    'A':['A10', 'A11', 'A12', 'A13'],
                    'D':['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key    A   D
# 0  K0  A10  D0
# 1  K1  A11  D1
# 2  K4  A12  D2
# 3  K5  A13  D3

# %%
pd.merge(left, right, on="key")
# Out:
#   key A_x   B  A_y   D
# 0  K0  A0  B0  A10  D0
# 1  K1  A1  B1  A11  D1

# %%
pd.merge(left, right, on="key", suffixes=['_left', '_right'])
# Out:
#   key A_left   B A_right   D
# 0  K0     A0  B0     A10  D0
# 1  K1     A1  B1     A11  D1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.DataFrame({'A':['A0', 'A1', 'A2', 'A3'],
                    'B':['B0', 'B1', 'B2', 'B3'],
                    'C':['C0', 'C1', 'C2', 'C3'],
                    'D':['D0', 'D1', 'D2', 'D3'],
                    'E':['E0', 'E1', 'E2', 'E3']
                   })
df1
# Out:
#     A   B   C   D   E
# 0  A0  B0  C0  D0  E0
# 1  A1  B1  C1  D1  E1
# 2  A2  B2  C2  D2  E2
# 3  A3  B3  C3  D3  E3

# %%
df2 = pd.DataFrame({'A':['A4', 'A5', 'A6', 'A7'],
                    'B':['B4', 'B5', 'B6', 'B7'],
                    'C':['C4', 'C5', 'C6', 'C7'],
                    'D':['D4', 'D5', 'D6', 'D7'],
                    'F':['F4', 'F5', 'F6', 'F7']
                   })
df2
# Out:
#     A   B   C   D   F
# 0  A4  B4  C4  D4  F4
# 1  A5  B5  C5  D5  F5
# 2  A6  B6  C6  D6  F6
# 3  A7  B7  C7  D7  F7

# %%
pd.concat([df1, df2])
# Out:
#     A   B   C   D    E    F
# 0  A0  B0  C0  D0   E0  NaN
# 1  A1  B1  C1  D1   E1  NaN
# 2  A2  B2  C2  D2   E2  NaN
# 3  A3  B3  C3  D3   E3  NaN
# 0  A4  B4  C4  D4  NaN   F4
# 1  A5  B5  C5  D5  NaN   F5
# 2  A6  B6  C6  D6  NaN   F6
# 3  A7  B7  C7  D7  NaN   F7

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
#     A   B   C   D    E    F
# 0  A0  B0  C0  D0   E0  NaN
# 1  A1  B1  C1  D1   E1  NaN
# 2  A2  B2  C2  D2   E2  NaN
# 3  A3  B3  C3  D3   E3  NaN
# 4  A4  B4  C4  D4  NaN   F4
# 5  A5  B5  C5  D5  NaN   F5
# 6  A6  B6  C6  D6  NaN   F6
# 7  A7  B7  C7  D7  NaN   F7

# %%
pd.concat([df1, df2], ignore_index=True, join='inner')
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1
# Out:
#     A   B   C   D   E
# 0  A0  B0  C0  D0  E0
# 1  A1  B1  C1  D1  E1
# 2  A2  B2  C2  D2  E2
# 3  A3  B3  C3  D3  E3

# %%
s1 = pd.Series(list(range(4)), name='F')
pd.concat([df1, s1], axis=1)
# Out:
#     A   B   C   D   E  F
# 0  A0  B0  C0  D0  E0  0
# 1  A1  B1  C1  D1  E1  1
# 2  A2  B2  C2  D2  E2  2
# 3  A3  B3  C3  D3  E3  3

# %%
s2 = df1.apply(lambda x:x['A']+'_GG', axis=1)
s2
# Out:
# 0    A0_GG
# 1    A1_GG
# 2    A2_GG
# 3    A3_GG
# dtype: object

# %%
s2.name='G'

# %%
pd.concat([df1, s1, s2], axis=1)
# Out:
#     A   B   C   D   E  F      G
# 0  A0  B0  C0  D0  E0  0  A0_GG
# 1  A1  B1  C1  D1  E1  1  A1_GG
# 2  A2  B2  C2  D2  E2  2  A2_GG
# 3  A3  B3  C3  D3  E3  3  A3_GG

# %%
pd.concat([s1, s2], axis=1)
# Out:
#    F      G
# 0  0  A0_GG
# 1  1  A1_GG
# 2  2  A2_GG
# 3  3  A3_GG

# %%
pd.concat([s1, df1, s2], axis=1)
# Out:
#    F   A   B   C   D   E      G
# 0  0  A0  B0  C0  D0  E0  A0_GG
# 1  1  A1  B1  C1  D1  E1  A1_GG
# 2  2  A2  B2  C2  D2  E2  A2_GG
# 3  3  A3  B3  C3  D3  E3  A3_GG

# %%
df1 = pd.DataFrame([[1, 2],[3, 4]], columns=list('AB'))
df1
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df2 = pd.DataFrame([[5, 6],[7, 8]], columns=list('AB'))
df2
# Out:
#    A  B
# 0  5  6
# 1  7  8

# %%
df1.append(df2)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
df1.append(df2, ignore_index=True)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
df = pd.DataFrame(columns=['A'])
df
# Out:
# Empty DataFrame
# Columns: [A]
# Index: []

# %%
for i in range(5):
    df = df.append({'A': i}, ignore_index=True)
df
# Out:
#    A
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
# Avoid multiple copies
pd.concat([pd.DataFrame([i], columns=['A']) for i in range(5)],
         ignore_index=True
         )
# Out:
#    A
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
work_dir = '/Users/huajiao/Desktop'
splits_dir = f"{work_dir}/splits"

import os
if not os.path.exists(splits_dir):
    os.mkdir(splits_dir)

# %%
df_source = pd.read_excel(f"{work_dir}/test.xlsx")

# %%
df_source.head()
# Out:
#    Unnamed: 0      名字      投票人数  类型   产地                 上映时间   时长    年代   评分  \
# 0           0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6
# 1           1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5
# 2           2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5
# 3           3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4
# 4           4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df_source.index
# Out:
# RangeIndex(start=0, stop=38738, step=1)

# %%
df_source.drop(labels="Unnamed: 0", axis=1)
# Out:
#                                                       名字      投票人数  类型   产地  \
# 0                                                 肖申克的救赎  692795.0  剧情   美国
# 1                                                   控方证人   42995.0  剧情   美国
# 2                                                  美丽人生   327855.0  剧情  意大利
# 3                                                   阿甘正传  580897.0  剧情   美国
# 4                                                   霸王别姬  478523.0  剧情   中国
# ...                                                  ...       ...  ..  ...
# 38733                                              神学院 S      46.0  情色   法国
# 38734                                              1935年      57.0  喜剧   美国
# 38735                                               血溅画屏      95.0  剧情   中国
# 38736                                             魔窟中的幻想      51.0  惊悚   中国
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...      32.0  剧情  俄罗斯
#
#                       上映时间   时长    年代   评分    首映地点
# ...

# %%
df_source.shape
# Out:
# (38738, 10)

# %%
total_row_count = df_source.shape[0]
total_row_count
# Out:
# 38738

# %%
user_names = ['a', 'b', 'c', 'd', 'e']

# %%
split_size = total_row_count // len(user_names)
if total_row_count % len(user_names) != 0:
    split_size += 1
split_size
# Out:
# 7748

# %%
df_subs = []
for idx, user_name in enumerate(user_names):
    begin = idx*split_size
    end = begin+split_size
    df_sub = df_source.iloc[begin:end]
    df_subs.append((idx, user_name, df_sub))

# %%
for idx, user_name, df_sub in df_subs:
    file_name = f'{splits_dir}/test_{idx}_{user_name}.xlsx'
    df_sub.to_excel(file_name, index=False)

# %%
import os
excel_names = []
for excel_name in os.listdir(splits_dir):
    excel_names.append(excel_name)
excel_names
# Out:
# ['test_4_e.xlsx',
#  'test_2_c.xlsx',
#  'test_1_b.xlsx',
#  'test_0_a.xlsx',
#  'test_3_d.xlsx']

# %%
df_list =[]

for excel_name in excel_names:
    excel_path = f'{splits_dir}/{excel_name}'
    df_split = pd.read_excel(excel_path)
    
    username = excel_name.replace("test_","").replace('.xlsx','')[2:]
    print(excel_name, username)
    df_split['username'] = username
    
    df_list.append(df_split)
# Out:
# test_4_e.xlsx e
# test_2_c.xlsx c
# test_1_b.xlsx b
# test_0_a.xlsx a
# test_3_d.xlsx d

# %%
df_merged = pd.concat(df_list)

# %%
df_merged.shape
# Out:
# (38738, 11)

# %%
df_merged.head()
# Out:
#    Unnamed: 0    名字    投票人数  类型  产地                 上映时间   时长    年代   评分  \
# 0       30992    压榨  1666.0  喜剧  美国  2009-09-04 00:00:00   92  2009  6.1
# 1       30993  压轴好戏   217.0  喜剧  法国  2008-11-05 00:00:00  101  2008  6.8
# 2       30994   压轴戏    29.0  恐怖  美国  2009-07-01 00:00:00   93  2009  3.3
# 3       30995    鸦片    65.0  同性  法国  2013-05-24 00:00:00   77  2013  5.9
# 4       30996  鸦片战争  3348.0  剧情  中国  1997-06-09 00:00:00  153  1997  7.1
#
#     首映地点 username
# 0     美国        e
# 1     美国        e
# 2     美国        e
# 3  戛纳电影节        e
# 4     北京        e

# %%
df_merged['username'].value_counts()
# Out:
# a    7748
# d    7748
# b    7748
# c    7748
# e    7746
# Name: username, dtype: int64

# %%
df_merged.to_excel(f'{work_dir}/teat_merged.xlsx', index=False)

# %%
# %matplotlib inline

# %%
df = pd.DataFrame({'A' : ['a', 'a', 'c', 'c', 'e', 'f'],
                   'B' : ['1', '2', '3', '3', '4', '4'],
                   'C' : np.random.randn(6),
                   'D' : np.random.randn(6)})

df
# Out:
#    A  B         C         D
# 0  a  1 -2.080293 -2.366282
# 1  a  2 -0.135793  0.424429
# 2  c  3 -0.282543 -0.070191
# 3  c  3  0.280406  0.124190
# 4  e  4  0.623542 -1.413865
# 5  f  4 -0.259397 -0.063592

# %%
df.groupby('A').sum()
# Out:
#           C         D
# A
# a -2.216086 -1.941853
# c -0.002137  0.053999
# e  0.623542 -1.413865
# f -0.259397 -0.063592

# %%
df.groupby(['A', 'B']).mean()
# Out:
#             C         D
# A B
# a 1 -2.080293 -2.366282
#   2 -0.135793  0.424429
# c 3 -0.001068  0.027000
# e 4  0.623542 -1.413865
# f 4 -0.259397 -0.063592

# %%
df.groupby(['A', 'B'], as_index=False).mean()
# Out:
#    A  B         C         D
# 0  a  1 -2.080293 -2.366282
# 1  a  2 -0.135793  0.424429
# 2  c  3 -0.001068  0.027000
# 3  e  4  0.623542 -1.413865
# 4  f  4 -0.259397 -0.063592

# %%
df.groupby('A').agg([np.sum, np.mean, np.std])
# Out:
#           C                             D
#         sum      mean       std       sum      mean       std
# A
# a -2.216086 -1.108043  1.374969 -1.941853 -0.970926  1.973330
# c -0.002137 -0.001068  0.398065  0.053999  0.027000  0.137448
# e  0.623542  0.623542       NaN -1.413865 -1.413865       NaN
# f -0.259397 -0.259397       NaN -0.063592 -0.063592       NaN

# %%
# select 'C' first, better
df.groupby('A')['C'].agg([np.sum, np.mean, np.std])
# Out:
#         sum      mean       std
# A
# a -2.216086 -1.108043  1.374969
# c -0.002137 -0.001068  0.398065
# e  0.623542  0.623542       NaN
# f -0.259397 -0.259397       NaN

# %%
df.groupby('A').agg([np.sum, np.mean, np.std])['C']
# Out:
#         sum      mean       std
# A
# a -2.216086 -1.108043  1.374969
# c -0.002137 -0.001068  0.398065
# e  0.623542  0.623542       NaN
# f -0.259397 -0.259397       NaN

# %%
df.groupby('A').agg({'C' : np.sum, 'D' : np.mean})
# Out:
#           C         D
# A
# a -2.216086 -0.970926
# c -0.002137  0.027000
# e  0.623542 -1.413865
# f -0.259397 -0.063592

# %%
g = df.groupby('A')
g

# %%
for name, group in g:
    print(name)
    print(group)
    print()
# Out:
# a
#    A  B         C         D
# 0  a  1 -2.080293 -2.366282
# 1  a  2 -0.135793  0.424429
#
# c
#    A  B         C         D
# 2  c  3 -0.282543 -0.070191
# 3  c  3  0.280406  0.124190
#
# e
#    A  B         C         D
# 4  e  4  0.623542 -1.413865
#
# f
#    A  B         C         D
# 5  f  4 -0.259397 -0.063592

# %%
g.get_group('a')
# Out:
#    A  B         C         D
# 0  a  1 -2.080293 -2.366282
# 1  a  2 -0.135793  0.424429

# %%
g = df.groupby(['A', 'B'])

# %%
for name, group in g:
    print(name)
    print(group)
    print()
# Out:
# ('a', '1')
#    A  B         C         D
# 0  a  1 -2.080293 -2.366282
#
# ('a', '2')
#    A  B         C         D
# 1  a  2 -0.135793  0.424429
#
# ('c', '3')
#    A  B         C         D
# 2  c  3 -0.282543 -0.070191
# 3  c  3  0.280406  0.124190
#
# ('e', '4')
#    A  B         C         D
# 4  e  4  0.623542 -1.413865
#
# ('f', '4')
#    A  B         C         D
# 5  f  4 -0.259397 -0.063592

# %%
g.get_group(('c', '3'))
# Out:
#    A  B         C         D
# 2  c  3 -0.282543 -0.070191
# 3  c  3  0.280406  0.124190

# %%
g['C']

# %%
for name, group in g['C']:
    print(name)
    print(group)
    print(type(group))
    print()
# Out:
# ('a', '1')
# 0   -2.080293
# Name: C, dtype: float64
# <class 'pandas.core.series.Series'>
#
# ('a', '2')
# 1   -0.135793
# Name: C, dtype: float64
# <class 'pandas.core.series.Series'>
#
# ('c', '3')
# 2   -0.282543
# 3    0.280406
# Name: C, dtype: float64
# <class 'pandas.core.series.Series'>
#
# ('e', '4')
# 4    0.623542
# Name: C, dtype: float64
# <class 'pandas.core.series.Series'>
#
# ('f', '4')
# 5   -0.259397
# Name: C, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
df = pd.read_excel("/Users/huajiao/Desktop/test.xlsx")

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#        名字      投票人数  类型   产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5     意大利
# 3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4      香港

# %%
data = df.groupby('年代')['评分'].max()
data
# Out:
# 年代
# 1888    8.7
# 1890    4.8
# 1892    7.5
# 1894    7.2
# 1895    8.5
#        ...
# 2012    9.9
# 2013    9.9
# 2014    9.8
# 2015    9.7
# 2016    9.3
# Name: 评分, Length: 126, dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='年代'>

# %%
df.dtypes
# Out:
# 名字       object
# 投票人数    float64
# 类型       object
# 产地       object
# 上映时间     object
# 时长       object
# 年代        int64
# 评分      float64
# 首映地点     object
# dtype: object

# %%
df['时长'].str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 38733    True
# 38734    True
# 38735    True
# 38736    True
# 38737    True
# Name: 时长, Length: 38738, dtype: object

# %%
data = df.groupby('年代').agg({'评分':np.mean, '投票人数':np.sum})
data
# Out:
#             评分         投票人数
# 年代
# 1888  7.950000       776.00
# 1890  4.800000        51.00
# 1892  7.500000       176.00
# 1894  6.633333       338.00
# 1895  7.575000      7679.00
# ...        ...          ...
# 2012  6.458374  14463052.00
# 2013  6.392604  15215050.00
# 2014  6.259777  14573872.00
# 2015  6.141960  12483522.87
# 2016  5.868217   1851413.00
#
# [126 rows x 2 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='年代'>

# %%
stocks = pd.read_excel('/Users/huajiao/Desktop/Book2.xlsx')

# %%
stocks.head(3)
# Out:
#          Date Company  Price   Open   High    Low   Vol.  Change %
# 0  09/29/2022       a  51.25  51.38  52.09  50.09  6.14M   -0.0317
# 1  09/28/2022       a  52.93  51.32  53.25  50.55  5.99M    0.0051
# 2  09/27/2022       a  52.66  54.03  55.06  52.17  6.13M   -0.0127

# %%
stocks.shape
# Out:
# (12, 8)

# %%
stocks['Company'].unique()
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
stocks.head(4)
# Out:
#          Date Company  Price   Open   High    Low    Vol.  Change %
# 0  09/29/2022       a  51.25  51.38  52.09  50.09   6.14M   -0.0317
# 1  09/28/2022       a  52.93  51.32  53.25  50.55   5.99M    0.0051
# 2  09/27/2022       a  52.66  54.03  55.06  52.17   6.13M   -0.0127
# 3  09/29/2022       b  79.06  78.05  79.19  76.74  17.91M   -0.0238

# %%
stocks.groupby('Company')['Price'].mean()
# Out:
# Company
# a     52.280000
# b     79.306667
# c      2.856667
# d    119.463333
# Name: Price, dtype: float64

# %%
ser = stocks.groupby(['Company', 'Date'])['Price'].mean()
ser
# Out:
# Company  Date
# a        09/27/2022     52.66
#          09/28/2022     52.93
#          09/29/2022     51.25
# b        09/27/2022     77.87
#          09/28/2022     80.99
#          09/29/2022     79.06
# c        09/27/2022      2.91
#          09/28/2022      2.89
#          09/29/2022      2.77
# d        09/27/2022    119.27
#          09/28/2022    121.40
#          09/29/2022    117.72
# Name: Price, dtype: float64

# %%
ser.index
# Out:
# MultiIndex([('a', '09/27/2022'),
#             ('a', '09/28/2022'),
#             ('a', '09/29/2022'),
#             ('b', '09/27/2022'),
#             ('b', '09/28/2022'),
#             ('b', '09/29/2022'),
#             ('c', '09/27/2022'),
#             ('c', '09/28/2022'),
#             ('c', '09/29/2022'),
#             ('d', '09/27/2022'),
#             ('d', '09/28/2022'),
#             ('d', '09/29/2022')],
#            names=['Company', 'Date'])

# %%
ser.unstack()
# Out:
# Date     09/27/2022  09/28/2022  09/29/2022
# Company
# a             52.66       52.93       51.25
# b             77.87       80.99       79.06
# c              2.91        2.89        2.77
# d            119.27      121.40      117.72

# %%
ser
# Out:
# Company  Date
# a        09/27/2022     52.66
#          09/28/2022     52.93
#          09/29/2022     51.25
# b        09/27/2022     77.87
#          09/28/2022     80.99
#          09/29/2022     79.06
# c        09/27/2022      2.91
#          09/28/2022      2.89
#          09/29/2022      2.77
# d        09/27/2022    119.27
#          09/28/2022    121.40
#          09/29/2022    117.72
# Name: Price, dtype: float64

# %%
ser.reset_index()
# Out:
#    Company        Date   Price
# 0        a  09/27/2022   52.66
# 1        a  09/28/2022   52.93
# 2        a  09/29/2022   51.25
# 3        b  09/27/2022   77.87
# 4        b  09/28/2022   80.99
# 5        b  09/29/2022   79.06
# 6        c  09/27/2022    2.91
# 7        c  09/28/2022    2.89
# 8        c  09/29/2022    2.77
# 9        d  09/27/2022  119.27
# 10       d  09/28/2022  121.40
# 11       d  09/29/2022  117.72

# %%
ser.loc['a']
# Out:
# Date
# 09/27/2022    52.66
# 09/28/2022    52.93
# 09/29/2022    51.25
# Name: Price, dtype: float64

# %%
ser.loc[('a', '09/27/2022')]
# Out:
# 52.66

# %%
ser.loc[:, '09/27/2022']
# Out:
# Company
# a     52.66
# b     77.87
# c      2.91
# d    119.27
# Name: Price, dtype: float64

# %%
stocks.set_index(['Company', 'Date'], inplace=True)
stocks
# Out:
#                      Price    Open    High     Low    Vol.  Change %
# Company Date
# a       09/29/2022   51.25   51.38   52.09   50.09   6.14M   -0.0317
#         09/28/2022   52.93   51.32   53.25   50.55   5.99M    0.0051
#         09/27/2022   52.66   54.03   55.06   52.17   6.13M   -0.0127
# b       09/29/2022   79.06   78.05   79.19   76.74  17.91M   -0.0238
#         09/28/2022   80.99   76.49   81.48   76.28  20.58M    0.0401
#         09/27/2022   77.87   79.43   80.41   77.10  16.81M   -0.0132
# c       09/29/2022    2.77    2.78    2.84    2.67   8.74M   -0.0415
#         09/28/2022    2.89    2.85    2.90    2.75   7.21M   -0.0069
#         09/27/2022    2.91    2.94    3.04    2.88   5.86M    0.0104
# d       09/29/2022  117.72  117.14  119.12  116.37   3.15M   -0.0303
#         09/28/2022  121.40  116.17  121.91  116.11   2.14M    0.0179
#         09/27/2022  119.27  119.60  122.22  118.25   1.73M   -0.0017

# %%
stocks.index
# Out:
# MultiIndex([('a', '09/29/2022'),
#             ('a', '09/28/2022'),
#             ('a', '09/27/2022'),
#             ('b', '09/29/2022'),
#             ('b', '09/28/2022'),
#             ('b', '09/27/2022'),
#             ('c', '09/29/2022'),
#             ('c', '09/28/2022'),
#             ('c', '09/27/2022'),
#             ('d', '09/29/2022'),
#             ('d', '09/28/2022'),
#             ('d', '09/27/2022')],
#            names=['Company', 'Date'])

# %%
stocks.sort_index(inplace=True)
stocks
# Out:
#                      Price    Open    High     Low    Vol.  Change %
# Company Date
# a       09/27/2022   52.66   54.03   55.06   52.17   6.13M   -0.0127
#         09/28/2022   52.93   51.32   53.25   50.55   5.99M    0.0051
#         09/29/2022   51.25   51.38   52.09   50.09   6.14M   -0.0317
# b       09/27/2022   77.87   79.43   80.41   77.10  16.81M   -0.0132
#         09/28/2022   80.99   76.49   81.48   76.28  20.58M    0.0401
#         09/29/2022   79.06   78.05   79.19   76.74  17.91M   -0.0238
# c       09/27/2022    2.91    2.94    3.04    2.88   5.86M    0.0104
#         09/28/2022    2.89    2.85    2.90    2.75   7.21M   -0.0069
#         09/29/2022    2.77    2.78    2.84    2.67   8.74M   -0.0415
# d       09/27/2022  119.27  119.60  122.22  118.25   1.73M   -0.0017
#         09/28/2022  121.40  116.17  121.91  116.11   2.14M    0.0179
#         09/29/2022  117.72  117.14  119.12  116.37   3.15M   -0.0303

# %%
stocks.loc['a']
# Out:
#             Price   Open   High    Low   Vol.  Change %
# Date
# 09/27/2022  52.66  54.03  55.06  52.17  6.13M   -0.0127
# 09/28/2022  52.93  51.32  53.25  50.55  5.99M    0.0051
# 09/29/2022  51.25  51.38  52.09  50.09  6.14M   -0.0317

# %%
stocks.loc[('a', '09/27/2022'),:]
# Out:
# Price        52.66
# Open         54.03
# High         55.06
# Low          52.17
# Vol.         6.13M
# Change %   -0.0127
# Name: (a, 09/27/2022), dtype: object

# %%
stocks.loc[('a', '09/27/2022'), 'Price']
# Out:
# 52.66

# %%
stocks.loc[['a', 'b'], 'Price']
# Out:
# Company  Date
# a        09/27/2022    52.66
#          09/28/2022    52.93
#          09/29/2022    51.25
# b        09/27/2022    77.87
#          09/28/2022    80.99
#          09/29/2022    79.06
# Name: Price, dtype: float64

# %%
stocks.loc[(['a', 'b'], '09/27/2022'), :]
# Out:
#                     Price   Open   High    Low    Vol.  Change %
# Company Date
# a       09/27/2022  52.66  54.03  55.06  52.17   6.13M   -0.0127
# b       09/27/2022  77.87  79.43  80.41  77.10  16.81M   -0.0132

# %%
stocks.loc[(['a', 'b'], '09/27/2022'), 'Price']
# Out:
# Company  Date
# a        09/27/2022    52.66
# b        09/27/2022    77.87
# Name: Price, dtype: float64

# %%
stocks.loc[('a', ['09/27/2022', '09/29/2022']), 'Price']
# Out:
# Company  Date
# a        09/27/2022    52.66
#          09/29/2022    51.25
# Name: Price, dtype: float64

# %%
stocks.loc[(slice(None), ['09/27/2022', '09/29/2022']), :]
# Out:
#                      Price    Open    High     Low    Vol.  Change %
# Company Date
# a       09/27/2022   52.66   54.03   55.06   52.17   6.13M   -0.0127
#         09/29/2022   51.25   51.38   52.09   50.09   6.14M   -0.0317
# b       09/27/2022   77.87   79.43   80.41   77.10  16.81M   -0.0132
#         09/29/2022   79.06   78.05   79.19   76.74  17.91M   -0.0238
# c       09/27/2022    2.91    2.94    3.04    2.88   5.86M    0.0104
#         09/29/2022    2.77    2.78    2.84    2.67   8.74M   -0.0415
# d       09/27/2022  119.27  119.60  122.22  118.25   1.73M   -0.0017
#         09/29/2022  117.72  117.14  119.12  116.37   3.15M   -0.0303

# %%
stocks = stocks.reset_index()
stocks
# Out:
#     index Company        Date   Price    Open    High     Low    Vol.  \
# 0       0       a  09/27/2022   52.66   54.03   55.06   52.17   6.13M
# 1       1       a  09/28/2022   52.93   51.32   53.25   50.55   5.99M
# 2       2       a  09/29/2022   51.25   51.38   52.09   50.09   6.14M
# 3       3       b  09/27/2022   77.87   79.43   80.41   77.10  16.81M
# 4       4       b  09/28/2022   80.99   76.49   81.48   76.28  20.58M
# 5       5       b  09/29/2022   79.06   78.05   79.19   76.74  17.91M
# 6       6       c  09/27/2022    2.91    2.94    3.04    2.88   5.86M
# 7       7       c  09/28/2022    2.89    2.85    2.90    2.75   7.21M
# 8       8       c  09/29/2022    2.77    2.78    2.84    2.67   8.74M
# 9       9       d  09/27/2022  119.27  119.60  122.22  118.25   1.73M
# 10     10       d  09/28/2022  121.40  116.17  121.91  116.11   2.14M
# 11     11       d  09/29/2022  117.72  117.14  119.12  116.37   3.15M
#
#     Change %
# 0    -0.0127
# 1     0.0051
# ...

# %%
# map, apply, applymap
dict_company_names = {'A': 'A1', 'B': 'B2', 'C': 'C3', 'D': 'D4'}

# %%
stocks.head(3)
# Out:
#    index Company        Date  Price   Open   High    Low   Vol.  Change %
# 0      0       a  09/27/2022  52.66  54.03  55.06  52.17  6.13M   -0.0127
# 1      1       a  09/28/2022  52.93  51.32  53.25  50.55  5.99M    0.0051
# 2      2       a  09/29/2022  51.25  51.38  52.09  50.09  6.14M   -0.0317

# %%
stocks['rename1'] = stocks['Company'].str.upper().map(dict_company_names)
stocks.head()
# Out:
#    index Company        Date  Price   Open   High    Low    Vol.  Change %  \
# 0      0       a  09/27/2022  52.66  54.03  55.06  52.17   6.13M   -0.0127
# 1      1       a  09/28/2022  52.93  51.32  53.25  50.55   5.99M    0.0051
# 2      2       a  09/29/2022  51.25  51.38  52.09  50.09   6.14M   -0.0317
# 3      3       b  09/27/2022  77.87  79.43  80.41  77.10  16.81M   -0.0132
# 4      4       b  09/28/2022  80.99  76.49  81.48  76.28  20.58M    0.0401
#
#   rename1
# 0      A1
# 1      A1
# 2      A1
# 3      B2
# 4      B2

# %%
stocks['rename2'] = stocks['Company'].map(lambda x: dict_company_names[x.upper()])
stocks.head()
# Out:
#    index Company        Date  Price   Open   High    Low    Vol.  Change %  \
# 0      0       a  09/27/2022  52.66  54.03  55.06  52.17   6.13M   -0.0127
# 1      1       a  09/28/2022  52.93  51.32  53.25  50.55   5.99M    0.0051
# 2      2       a  09/29/2022  51.25  51.38  52.09  50.09   6.14M   -0.0317
# 3      3       b  09/27/2022  77.87  79.43  80.41  77.10  16.81M   -0.0132
# 4      4       b  09/28/2022  80.99  76.49  81.48  76.28  20.58M    0.0401
#
#   rename1 rename2
# 0      A1      A1
# 1      A1      A1
# 2      A1      A1
# 3      B2      B2
# 4      B2      B2

# %%
stocks['rename3'] = stocks['Company'].apply(
    lambda x:dict_company_names[x.upper()])
stocks.head()
# Out:
#    index Company        Date  Price   Open   High    Low    Vol.  Change %  \
# 0      0       a  09/27/2022  52.66  54.03  55.06  52.17   6.13M   -0.0127
# 1      1       a  09/28/2022  52.93  51.32  53.25  50.55   5.99M    0.0051
# 2      2       a  09/29/2022  51.25  51.38  52.09  50.09   6.14M   -0.0317
# 3      3       b  09/27/2022  77.87  79.43  80.41  77.10  16.81M   -0.0132
# 4      4       b  09/28/2022  80.99  76.49  81.48  76.28  20.58M    0.0401
#
#   rename1 rename2 rename3
# 0      A1      A1      A1
# 1      A1      A1      A1
# 2      A1      A1      A1
# 3      B2      B2      B2
# 4      B2      B2      B2

# %%
stocks['rename4'] = stocks.apply(
    lambda x:dict_company_names[x['Company'].upper()],
    axis=1)
stocks.head()
# Out:
#    index Company        Date  Price   Open   High    Low    Vol.  Change %  \
# 0      0       a  09/27/2022  52.66  54.03  55.06  52.17   6.13M   -0.0127
# 1      1       a  09/28/2022  52.93  51.32  53.25  50.55   5.99M    0.0051
# 2      2       a  09/29/2022  51.25  51.38  52.09  50.09   6.14M   -0.0317
# 3      3       b  09/27/2022  77.87  79.43  80.41  77.10  16.81M   -0.0132
# 4      4       b  09/28/2022  80.99  76.49  81.48  76.28  20.58M    0.0401
#
#   rename1 rename2 rename3 rename4
# 0      A1      A1      A1      A1
# 1      A1      A1      A1      A1
# 2      A1      A1      A1      A1
# 3      B2      B2      B2      B2
# 4      B2      B2      B2      B2

# %%
sub_df = stocks[['Price', 'Open', 'High', 'Low', 'Vol.']]
sub_df['Vol.'] = sub_df['Vol.'].str.replace('M','').astype('float')
sub_df.head(3)
# Out:
#    Price   Open   High    Low  Vol.
# 0  52.66  54.03  55.06  52.17  6.13
# 1  52.93  51.32  53.25  50.55  5.99
# 2  51.25  51.38  52.09  50.09  6.14

# %%
sub_df.applymap(lambda x:int(x))
# Out:
#     Price  Open  High  Low  Vol.
# 0      52    54    55   52     6
# 1      52    51    53   50     5
# 2      51    51    52   50     6
# 3      77    79    80   77    16
# 4      80    76    81   76    20
# 5      79    78    79   76    17
# 6       2     2     3    2     5
# 7       2     2     2    2     7
# 8       2     2     2    2     8
# 9     119   119   122  118     1
# 10    121   116   121  116     2
# 11    117   117   119  116     3

# %%
stocks.loc[:, ['Price', 'Open', 'High', 'Low', 'Vol.']] = sub_df.applymap(lambda x:int(x))

# %%
stocks.head()
# Out:
#    index Company        Date  Price  Open  High  Low  Vol.  Change % rename1  \
# 0      0       a  09/27/2022     52    54    55   52     6   -0.0127      A1
# 1      1       a  09/28/2022     52    51    53   50     5    0.0051      A1
# 2      2       a  09/29/2022     51    51    52   50     6   -0.0317      A1
# 3      3       b  09/27/2022     77    79    80   77    16   -0.0132      B2
# 4      4       b  09/28/2022     80    76    81   76    20    0.0401      B2
#
#   rename2 rename3 rename4
# 0      A1      A1      A1
# 1      A1      A1      A1
# 2      A1      A1      A1
# 3      B2      B2      B2
# 4      B2      B2      B2

# %%
df_ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
def ratings_norm(df):
    min_value = df['Rating'].min()
    max_value = df['Rating'].max()
    df['Rating_norm'] = df['Rating'].apply(
        lambda x: (x-min_value)/(max_value - min_value))
    return df    

df_ratings = df_ratings.groupby('UserID').apply(ratings_norm)

# %%
df_ratings[df_ratings['UserID']==1].head()
# Out:
#    UserID  MovieID  Rating  Timestamp  Rating_norm
# 0       1     1193       5  978300760          1.0
# 1       1      661       3  978302109          0.0
# 2       1      914       3  978301968          0.0
# 3       1     3408       4  978300275          0.5
# 4       1     2355       5  978824291          1.0

# %%
df = pd.read_excel("/Users/huajiao/Desktop/test.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0      名字      投票人数  类型   产地                 上映时间   时长    年代   评分  \
# 0           0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6
# 1           1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5
# 2           2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5
# 3           3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4
# 4           4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df['year'] = df['年代'].astype('str').str[:2]
df.head()
# Out:
#    Unnamed: 0      名字      投票人数  类型   产地                 上映时间   时长    年代   评分  \
# 0           0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6
# 1           1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5
# 2           2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5
# 3           3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4
# 4           4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点 year
# 0  多伦多电影节   19
# 1      美国   19
# 2     意大利   19
# 3   洛杉矶首映   19
# 4      香港   19

# %%
df['year'].value_counts()
# Out:
# 20    24394
# 19    14314
# 18       30
# Name: year, dtype: int64

# %%
def get_top_n(df, n):
    return df.sort_values(by='评分')[['年代', '评分']][-n:]
df.groupby('year').apply(get_top_n, n=2).head(10)
# Out:
#               年代   评分
# year
# 18   1700   1888  8.7
#      203    1896  8.8
# 19   23559  1973  9.9
#      13882  1997  9.9
# 20   35470  2013  9.9
#      25273  2002  9.9

# %%
# pandas groupby: split, apply, combine

# %%
df_ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp  Rating_norm               pdate
# 0       1     1193       5  978300760          1.0 2000-12-31 22:12:40
# 1       1      661       3  978302109          0.0 2000-12-31 22:35:09
# 2       1      914       3  978301968          0.0 2000-12-31 22:32:48
# 3       1     3408       4  978300275          0.5 2000-12-31 22:04:35
# 4       1     2355       5  978824291          1.0 2001-01-06 23:38:11

# %%
df_ratings['pdate'] = pd.to_datetime(df_ratings['Timestamp'], unit='s')

# %%
df_ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp  Rating_norm               pdate
# 0       1     1193       5  978300760          1.0 2000-12-31 22:12:40
# 1       1      661       3  978302109          0.0 2000-12-31 22:35:09
# 2       1      914       3  978301968          0.0 2000-12-31 22:32:48
# 3       1     3408       4  978300275          0.5 2000-12-31 22:04:35
# 4       1     2355       5  978824291          1.0 2001-01-06 23:38:11

# %%
df_ratings.dtypes
# Out:
# UserID                  int64
# MovieID                 int64
# Rating                  int64
# Timestamp               int64
# Rating_norm           float64
# pdate          datetime64[ns]
# dtype: object

# %%
df_group = df_ratings.groupby([df_ratings['pdate'].dt.month, 'Rating'])['UserID'].agg(pv=np.sum)

# %%
df_group.head(20)
# Out:
#                     pv
# pdate Rating
# 1     1        2613452
#       2        5294359
#       3       12273331
#       4       16452340
#       5        9580889
# 2     1        1608795
#       2        3747792
#       3        8608216
#       4       10941690
#       5        5819374
# 3     1        1344378
#       2        2772172
#       3        6156512
#       4        6911661
#       5        3228406
# 4     1        4397883
#       2       10147641
#       3       25330546
#       4       30406281
#       5       18070625

# %%
df_stack = df_group.unstack()
df_stack
# Out:
#               pv
# Rating         1         2          3          4          5
# pdate
# 1        2613452   5294359   12273331   16452340    9580889
# 2        1608795   3747792    8608216   10941690    5819374
# 3        1344378   2772172    6156512    6911661    3228406
# 4        4397883  10147641   25330546   30406281   18070625
# 5       24893943  41021601   99671422  138699142   98385825
# 6       15896973  31940801   75297592  109067096   72816021
# 7       22506252  44079974  118016191  163188814  104777329
# 8       42290096  80215303  196812819  250299153  165391463
# 9       10185866  19751997   49514561   66638484   43733790
# 10       6825621  14936083   37937741   49413212   31949765
# 11      29762500  55254306  133879416  181288004  118358977
# 12       5474475  11043533   25870578   33351106   19000303

# %%
df_stack.plot()
# Out:
# <AxesSubplot:xlabel='pdate'>

# %%
df_stack.stack().head(20)
# Out:
#                     pv
# pdate Rating
# 1     1        2613452
#       2        5294359
#       3       12273331
#       4       16452340
#       5        9580889
# 2     1        1608795
#       2        3747792
#       3        8608216
#       4       10941690
#       5        5819374
# 3     1        1344378
#       2        2772172
#       3        6156512
#       4        6911661
#       5        3228406
# 4     1        4397883
#       2       10147641
#       3       25330546
#       4       30406281
#       5       18070625

# %%
df_group.head(20)
# Out:
#                     pv
# pdate Rating
# 1     1        2613452
#       2        5294359
#       3       12273331
#       4       16452340
#       5        9580889
# 2     1        1608795
#       2        3747792
#       3        8608216
#       4       10941690
#       5        5819374
# 3     1        1344378
#       2        2772172
#       3        6156512
#       4        6911661
#       5        3228406
# 4     1        4397883
#       2       10147641
#       3       25330546
#       4       30406281
#       5       18070625

# %%
df_reset = df_group.reset_index()
df_reset.head()
# Out:
#    pdate  Rating        pv
# 0      1       1   2613452
# 1      1       2   5294359
# 2      1       3  12273331
# 3      1       4  16452340
# 4      1       5   9580889

# %%
df_pivot = df_reset.pivot('pdate', 'Rating', 'pv')

# %%
df_pivot.head(10)
# Out:
# Rating         1         2          3          4          5
# pdate
# 1        2613452   5294359   12273331   16452340    9580889
# 2        1608795   3747792    8608216   10941690    5819374
# 3        1344378   2772172    6156512    6911661    3228406
# 4        4397883  10147641   25330546   30406281   18070625
# 5       24893943  41021601   99671422  138699142   98385825
# 6       15896973  31940801   75297592  109067096   72816021
# 7       22506252  44079974  118016191  163188814  104777329
# 8       42290096  80215303  196812819  250299153  165391463
# 9       10185866  19751997   49514561   66638484   43733790
# 10       6825621  14936083   37937741   49413212   31949765

# %%
df_pivot.plot()
# Out:
# <AxesSubplot:xlabel='pdate'>

# %%
# def my_func(row):
#     new_column = row['a'] + row['b']
#     return new_column
# df['new_column'] = df.apply(my_func, axis=1)

# def my_func(row):
#     new_a, new_b = row['a'] + row['b'], row['a'] - row['b']
#     return new_a, new_b
# df[['new_a', 'new_b']] = df.apply(my_func, axis=1, result_type='expand')

# %%
df.head()
# Out:
#    Unnamed: 0      名字      投票人数  类型   产地                 上映时间   时长    年代   评分  \
# 0           0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6
# 1           1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5
# 2           2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5
# 3           3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4
# 4           4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点 year
# 0  多伦多电影节   19
# 1      美国   19
# 2     意大利   19
# 3   洛杉矶首映   19
# 4      香港   19

# %%
df['时长'].dtypes
# Out:
# dtype('O')

# %%
df['时长'].value_counts()
# Out:
# 60     6141
# 90     1662
# 100    1056
# 95     1025
# 93      862
#        ...
# 395       1
# 260       1
# 635       1
# 275       1
# 3         1
# Name: 时长, Length: 391, dtype: int64

# %%
df['时长'].str.isnumeric().value_counts()
# Out:
# True     38600
# False        2
# Name: 时长, dtype: int64

# %%
ls = df[df['时长'].str.isnumeric()==False].index

# %%
df.loc[df['时长'].str.isnumeric()==False, '时长'] = df['时长'].str[:-1]

# %%
ls
# Out:
# Int64Index([31644, 32949], dtype='int64')

# %%
df.loc[ls[0]]
# Out:
# Unnamed: 0                  31644
# 名字                       一个被隔绝的世界
# 投票人数                         46.0
# 类型                            纪录片
# 产地                             瑞典
# 上映时间          1948-10-25 00:00:00
# 时长                              8
# 年代                           1948
# 评分                            7.8
# 首映地点                           美国
# year                           19
# Name: 31644, dtype: object

# %%
df['时长'].str.isnumeric().value_counts()
# Out:
# True    38602
# Name: 时长, dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# 名字             object
# 投票人数          float64
# 类型             object
# 产地             object
# 上映时间           object
# 时长             object
# 年代              int64
# 评分            float64
# 首映地点           object
# year           object
# dtype: object

# %%
def my_func(row):
    return float(row['year'])*row['评分'], row['投票人数']*row['评分']
    
df[['year*评分', '投票人数*评分']] = df.apply(my_func, axis=1, result_type='expand')

# %%
df.head()
# Out:
#    Unnamed: 0      名字      投票人数  类型   产地                 上映时间   时长    年代   评分  \
# 0           0  肖申克的救赎  692795.0  剧情   美国  1994-09-10 00:00:00  142  1994  9.6
# 1           1    控方证人   42995.0  剧情   美国  1957-12-17 00:00:00  116  1957  9.5
# 2           2   美丽人生   327855.0  剧情  意大利  1997-12-20 00:00:00  116  1997  9.5
# 3           3    阿甘正传  580897.0  剧情   美国  1994-06-23 00:00:00  142  1994  9.4
# 4           4    霸王别姬  478523.0  剧情   中国  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点 year  year*评分    投票人数*评分
# 0  多伦多电影节   19    182.4  6650832.0
# 1      美国   19    180.5   408452.5
# 2     意大利   19    180.5  3114622.5
# 3   洛杉矶首映   19    178.6  5460431.8
# 4      香港   19    178.6  4498116.2
